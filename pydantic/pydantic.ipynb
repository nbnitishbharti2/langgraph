# %% [markdown]
# ### Pydantic

# %% [markdown]
# ### Pydantic Bacics: Creating and Using Models
#
# Pydantic models are the foundation of data validation in Python. They use Python type annotations to define
# the structure and validate data at runtime. Here's a detailed exploration of basic model creation with several examples.

# %%
from pydantic import BaseModel

# %%
from dataclasses import dataclass

@dataclass
class Person():
  name:str
  age:int
  city:str

person = Person(name="Nitish", age=35, city="Banglore")
print(person)
# Out:
# Person(name='Nitish', age=35, city='Banglore')

# %%
person = Person(name="Nitish", age="three", city="Banglore")
print(person)
# Out:
# Person(name='Nitish', age='three', city='Banglore')

# %%
class Person1(BaseModel):
  name:str
  age:int
  city:str

person = Person1(name="Nitish", age=35, city="Banglore")
print(person)
# Out:
# name='Nitish' age=35 city='Banglore'

# %%
person1 = Person1(name="Nitish", age="three", city="Banglore")
print(person1)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 person1 = Person1(name="Nitish", age="three", city="Banglore")
#       2 print(person1)
#
# File d:\PHP8.2\htdocs\learning\python-learning\langgraph\.venv\Lib\site-packages\pydantic\main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
#     267         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
# ...

# %% [markdown]
# ## 2. Model with Optional Fields
#
# Add optional fields using Python's Optional type:

# %% [markdown]
# Defnition
# - Optional[type]: Indicates the field can be None
# - Default value (= None or = True): Makes the field optional
# - Required fields must still be provided
# - Pydantic validates types even for optional fields when values are provided

# %%
from typing import Optional

class Employee(BaseModel):
  id: int
  name: str
  department: str
  salary: Optional[float] = None # Optional with default value
  is_active: Optional[bool] = True # Optional with default True

# %%
# Examples with and without optional fields
emp1 = Employee(id=1, name="John", department="IT")
print(emp1) # id=1 name="John" department="IT" salary=None is_active=True
# Out:
# id=1 name='John' department='IT' salary=None is_active=True

# %%
emp2 = Employee(id=1, name="John", department="IT", salary=60000, is_active=False)
print(emp2) # id=1 name='John' department='IT' salary=60000.0 is_active=False
# Out:
# id=1 name='John' department='IT' salary=60000.0 is_active=False

# %%
from pydantic import BaseModel
from typing import List

class ClassRoom(BaseModel):
  room_number: str
  students: List[str]
  capacity: int

# %%
# Create a classroom
classroom = ClassRoom(
  room_number="A101",
  students=["Alice", "Bob", "Charlie"],
  capacity=30
)

print(classroom)
# Out:
# room_number='A101' students=['Alice', 'Bob', 'Charlie'] capacity=30

# %%
try:
  invalid_val = ClassRoom(room_number="S1", students=["Krish", 123], capacity=20)
except ValueError as e:
  print(e)
# Out:
# 1 validation error for ClassRoom
# students.1
#   Input should be a valid string [type=string_type, input_value=123, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_type

# %% [markdown]
# ### 4. Model with Nested Models
#
# Create complex structure with nested models:

# %%
class Address(BaseModel):
  street: str
  city: str
  zip_code: str

class Customer(BaseModel):
  customer_id: int
  name: str
  address: Address # Nested model

# Create a customer with nested address
customer = Customer(
  customer_id=11,
  name="Alice",
  address={
    "street": "123 Main St", "city": "mumbai", "zip_code": "02108"
  }
)

print(customer)
# Out:
# customer_id=11 name='Alice' address=Address(street='123 Main St', city='mumbai', zip_code='02108')

# %% [markdown]
# #### Pydantic Fields: Customization and Constraints
#
# The Field function in Pydantic enhances model fields beyond basic type hints by allowing you to
# specify validation rules, default values, aliases, and more. Here's a comprehensive tutorial with examples.

# %%
from pydantic import BaseModel, Field

class Item(BaseModel):
  name: str = Field(min_length=2, max_length=50)
  price: float = Field(ge = 0, le = 1000)
  quantity: int = Field(ge=0)

# Valid Instance
item = Item(name="Book", price=10, quantity=0)
print(item)
# Out:
# name='Book' price=10.0 quantity=0

# %%
from pydantic import BaseModel, Field

class User(BaseModel):
  username: str = Field(..., description="Unique username for the user")
  age: int = Field(default=18, description="User age, defaults to 18")
  email: str = Field(default_factory=lambda: "user@example.com", description="Default email address")

# Examples
user1 = User(username="alice")
print(user1) # username='alice' age=18 email='user@example.com'

user2 = User(username="bob", age=25, email="bob@gmail.com")
print(user2) # username='bob' age=25 email='bob@gmail.com'
# Out:
# username='alice' age=18 email='user@example.com'
# username='bob' age=25 email='bob@gmail.com'
